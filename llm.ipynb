# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.6,
    google_api_key=GEMINI_API_KEY
)

response = llm.invoke("What is LLM?")
print(response.content)
# Out:
# An **LLM** stands for **Large Language Model**.
#
# It's a type of artificial intelligence (AI) program designed to understand, generate, and process human-like text.
#
# Here's a breakdown of what each part of the name signifies:
#
# 1.  **Large:**
#     *   **Data:** LLMs are trained on *massive* amounts of text data – often trillions of words scraped from the internet (books, articles, websites, code, conversations, etc.).
#     *   **Parameters:** They have billions, even trillions, of "parameters." These are the internal variables or weights that the model adjusts during its training to learn patterns, relationships, and nuances in the language. More parameters generally mean the model can learn more complex patterns and achieve higher performance.
#
# 2.  **Language:**
#     *   Their primary domain is human language. They are designed to process, understand, and generate text in a way that mimics human communication.
#     *   They learn grammar, syntax, semantics, context, facts, reasoning abilities, and even creative writing styles from the vast datasets they consume.
#
# 3.  **Model:**
#     *   It's a mathematical construct or algorithm. It's not a sentient being, but a sophisticated piece of software that has learned to represent and predict language patterns based on its training.
#     *   The core mechanism for many LLMs involves predicting the most probable next word in a sequence, given the words that came before it. This seemingly simple task allows them to perform complex operations like generating coherent paragraphs, answering questions, or summarizing text.
#
# **How they work (simplified):**
#
# During training, an LLM analyzes patterns in the vast text data. For example, it learns that after "The capital of France is...", the word "Paris" is highly probable. It learns context, common phrases, factual information, and even how different concepts relate to each other.
#
# Once trained, when you give an LLM a "prompt" (a question or instruction), it uses its learned knowledge to predict the most likely sequence of words that would logically follow, generating a response.
#
# **Key Capabilities & Applications:**
#
# *   **Generating text:** Writing articles, stories, poems, code, emails, marketing copy.
# *   **Answering questions:** Providing information on a wide range of topics.
# *   **Summarizing text:** Condensing long documents into shorter versions.
# *   **Translating languages:** Converting text from one language to another.
# *   **Chatbots & Conversational AI:** Powering interactive assistants.
# *   **Brainstorming & Idea Generation:** Helping users explore concepts.
# *   **Code generation and debugging:** Assisting programmers.
#
# **Examples of popular LLMs:**
#
# *   OpenAI's **GPT** series (e.g., GPT-3, GPT-4)
# *   Google's **PaLM**, **Gemini**
# *   Meta's **Llama**
# *   Anthropic's **Claude**
#
# In essence, an LLM is a powerful AI that has learned the intricate rules and patterns of human language to a remarkable degree, allowing it to perform a wide variety of text-based tasks.

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()
OPEN_API_KEY = os.getenv("OPEN_API_KEY")
